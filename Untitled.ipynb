# %%
import time
import jwt



def encode_jwt_token(ak, sk):
    headers = {
        "alg": "HS256",
        "typ": "JWT"
    }
    payload = {
        "iss": ak,
        "exp": int(time.time()) + 1800, # 有效时间，此处示例代表当前时间+1800s(30min)
        "nbf": int(time.time()) - 5 # 开始生效的时间，此处示例代表当前时间-5秒
    }
    token = jwt.encode(payload, sk, headers=headers)
    return token

api_token = encode_jwt_token(ak, sk)
print(api_token) # 打印生成的API_TOKEN
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJiNmQwNDc0YTA1NzI0YmQzOGRkMzZkMWU2ZTIzOTlhMyIsImV4cCI6MTc0MDUwNjk5NywibmJmIjoxNzQwNTA1MTkyfQ.CweVhCeLfw8Tvcza6KWbcTheIBLgDV1VXY1M3WBPV4E
